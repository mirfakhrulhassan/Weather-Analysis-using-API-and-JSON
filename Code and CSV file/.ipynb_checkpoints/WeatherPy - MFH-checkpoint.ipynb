# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

print("Beginning Data Retrieval")
print("----------------------------------------------")


citi = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []
chunks = [cities[x1:x1+50] for x1 in range(0, len(cities), 50)]
x3=0
for x2 in range(0,len(chunks)):
     for x3 in range(len(chunks[x2])):
        try:
            query_url = url+"units=Imperial" + "&appid=" + api_key + "&q=" + chunks[x2][x3]
            response = requests.get(query_url)
            print(f"processing Record {x3+1} of Set {x2+1} | {chunks[x2][x3]}")
            print(response.url)
            data = response.json()
            citi.append(data['name'])
            cloudiness.append(data['clouds']['all'])
            country.append(data['sys']['country'])
            date.append(data['dt'])
            humidity.append(data['main']['humidity'])
            latitude.append(data['coord']['lat'])
            longitude.append(data['coord']['lon'])
            max_temp.append(data['main']['temp_max'])
            wind_speed.append(data['wind']['speed'])
    
   
        except   KeyError:
           print("City not found. Skipping....")

    time.sleep(1)  
    
print("----------------------------------------------")
print("Data Retrieval Complete")
print("----------------------------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------------------------
# processing Record 1 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=barrow
# processing Record 2 of Set 1 | karpathos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=karpathos
# processing Record 3 of Set 1 | barroualie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=barroualie
# City not found. Skipping....
# processing Record 4 of Set 1 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=cayenne
# processing Record 5 of Set 1 | lithakia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=lithakia
# processing Record 6 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=rikitea
# processing Record 7 of Set 1 | acuexcomac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=acuexcomac
# City not found. Skipping....
# processing Record 8 of Set 1 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=maceio
# processing Record 9 of Set 1 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=vaitupu
# City not found. Skipping....
# processing Record 10 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=jamestown
# processing Record 11 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=barentsburg
# City not found. Skipping....
# processing Record 12 of Set 1 | zeya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=zeya
# processing Record 13 of Set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=lompoc
# processing Record 14 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=yellowknife
# processing Record 15 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=avarua
# processing Record 16 of Set 1 | batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=batagay
# processing Record 17 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=castro
# processing Record 18 of Set 1 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=belyy%20yar
# processing Record 19 of Set 1 | wainwright
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=wainwright
# processing Record 20 of Set 1 | lira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=lira
# processing Record 21 of Set 1 | harrison
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=harrison
# processing Record 22 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=hithadhoo
# processing Record 23 of Set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=amderma
# City not found. Skipping....
# processing Record 24 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=busselton
# processing Record 25 of Set 1 | bani walid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bani%20walid
# processing Record 26 of Set 1 | le vauclin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=le%20vauclin
# processing Record 27 of Set 1 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bonavista
# processing Record 28 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=punta%20arenas
# processing Record 29 of Set 1 | kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kurilsk
# processing Record 30 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=hermanus
# processing Record 31 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ushuaia
# processing Record 32 of Set 1 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=abu%20samrah
# processing Record 33 of Set 1 | boulsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=boulsa
# processing Record 34 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=port%20alfred
# processing Record 35 of Set 1 | ouargaye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ouargaye
# processing Record 36 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=taolanaro
# City not found. Skipping....
# processing Record 37 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=albany
# processing Record 38 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=new%20norfolk
# processing Record 39 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=qaanaaq
# processing Record 40 of Set 1 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ust-nera
# processing Record 41 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=arraial%20do%20cabo
# processing Record 42 of Set 1 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=broome
# processing Record 43 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bredasdorp
# processing Record 44 of Set 1 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=beringovskiy
# processing Record 45 of Set 1 | dzhusaly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=dzhusaly
# City not found. Skipping....
# processing Record 46 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=hobart
# processing Record 47 of Set 1 | at-bashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=at-bashi
# processing Record 48 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=cape%20town
# processing Record 49 of Set 1 | polyarnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=polyarnyy
# processing Record 50 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kapaa
# processing Record 1 of Set 2 | harindanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=harindanga
# processing Record 2 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=mar%20del%20plata
# processing Record 3 of Set 2 | guiyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=guiyang
# processing Record 4 of Set 2 | quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=quelimane
# processing Record 5 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bluff
# processing Record 6 of Set 2 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=saldanha
# processing Record 7 of Set 2 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=prince%20rupert
# processing Record 8 of Set 2 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=halalo
# City not found. Skipping....
# processing Record 9 of Set 2 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kaitangata
# processing Record 10 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=georgetown
# processing Record 11 of Set 2 | san rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=san%20rafael
# processing Record 12 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=hilo
# processing Record 13 of Set 2 | badiraguato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=badiraguato
# processing Record 14 of Set 2 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=mataura
# processing Record 15 of Set 2 | bikaner
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bikaner
# processing Record 16 of Set 2 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kazalinsk
# City not found. Skipping....
# processing Record 17 of Set 2 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=coihaique
# processing Record 18 of Set 2 | omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=omboue
# processing Record 19 of Set 2 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=mys%20shmidta
# City not found. Skipping....
# processing Record 20 of Set 2 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=san%20patricio
# processing Record 21 of Set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nikolskoye
# processing Record 22 of Set 2 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=hofn
# processing Record 23 of Set 2 | logrono
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=logrono
# processing Record 24 of Set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ilulissat
# processing Record 25 of Set 2 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bargal
# City not found. Skipping....
# processing Record 26 of Set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=vaini
# processing Record 27 of Set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=chokurdakh
# processing Record 28 of Set 2 | majene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=majene
# processing Record 29 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=illoqqortoormiut
# City not found. Skipping....
# processing Record 30 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=severo-kurilsk
# processing Record 31 of Set 2 | kayiry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kayiry
# processing Record 32 of Set 2 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sitka
# processing Record 33 of Set 2 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=cairns
# processing Record 34 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=dikson
# processing Record 35 of Set 2 | murray bridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=murray%20bridge
# processing Record 36 of Set 2 | shenzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=shenzhen
# processing Record 37 of Set 2 | durant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=durant
# processing Record 38 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=east%20london
# processing Record 39 of Set 2 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=verkhoyansk
# processing Record 40 of Set 2 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bur%20gabo
# City not found. Skipping....
# processing Record 41 of Set 2 | humaita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=humaita
# processing Record 42 of Set 2 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=alofi
# processing Record 43 of Set 2 | srostki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=srostki
# processing Record 44 of Set 2 | bentiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bentiu
# City not found. Skipping....
# processing Record 45 of Set 2 | strathmore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=strathmore
# processing Record 46 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=saint-philippe
# processing Record 47 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=atuona
# processing Record 48 of Set 2 | oksfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=oksfjord
# processing Record 49 of Set 2 | gimli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=gimli
# processing Record 50 of Set 2 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=mount%20isa
# processing Record 1 of Set 3 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=saint%20george
# processing Record 2 of Set 3 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=klyuchi
# processing Record 3 of Set 3 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ancud
# processing Record 4 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=butaritari
# processing Record 5 of Set 3 | nyagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nyagan
# processing Record 6 of Set 3 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=laguna
# processing Record 7 of Set 3 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=lata
# processing Record 8 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=port%20elizabeth
# processing Record 9 of Set 3 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=cherskiy
# processing Record 10 of Set 3 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tuktoyaktuk
# processing Record 11 of Set 3 | haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=haibowan
# City not found. Skipping....
# processing Record 12 of Set 3 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=grand%20river%20south%20east
# City not found. Skipping....
# processing Record 13 of Set 3 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=marcona
# City not found. Skipping....
# processing Record 14 of Set 3 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=jumla
# processing Record 15 of Set 3 | kainantu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kainantu
# processing Record 16 of Set 3 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=haines%20junction
# processing Record 17 of Set 3 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=korla
# City not found. Skipping....
# processing Record 18 of Set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=provideniya
# processing Record 19 of Set 3 | aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=aksu
# processing Record 20 of Set 3 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kahului
# processing Record 21 of Set 3 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kruisfontein
# processing Record 22 of Set 3 | kunmadaras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kunmadaras
# processing Record 23 of Set 3 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=alyangula
# processing Record 24 of Set 3 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tomatlan
# processing Record 25 of Set 3 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=labuhan
# processing Record 26 of Set 3 | la union
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=la%20union
# processing Record 27 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=upernavik
# processing Record 28 of Set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=khatanga
# processing Record 29 of Set 3 | barcelos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=barcelos
# processing Record 30 of Set 3 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=rio%20grande
# processing Record 31 of Set 3 | garowe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=garowe
# processing Record 32 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=carnarvon
# processing Record 33 of Set 3 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=praia%20da%20vitoria
# processing Record 34 of Set 3 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=samalaeulu
# City not found. Skipping....
# processing Record 35 of Set 3 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=cabo%20san%20lucas
# processing Record 36 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kodiak
# processing Record 37 of Set 3 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tsihombe
# City not found. Skipping....
# processing Record 38 of Set 3 | rio cuarto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=rio%20cuarto
# processing Record 39 of Set 3 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tromso
# processing Record 40 of Set 3 | sumbawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sumbawa
# City not found. Skipping....
# processing Record 41 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kavieng
# processing Record 42 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=constitucion
# processing Record 43 of Set 3 | arrifes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=arrifes
# processing Record 44 of Set 3 | celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=celestun
# processing Record 45 of Set 3 | ardesen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ardesen
# processing Record 46 of Set 3 | barawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=barawe
# City not found. Skipping....
# processing Record 47 of Set 3 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=leningradskiy
# processing Record 48 of Set 3 | chiang mai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=chiang%20mai
# processing Record 49 of Set 3 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=walvis%20bay
# processing Record 50 of Set 3 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nantucket
# processing Record 1 of Set 4 | yeniseysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=yeniseysk
# processing Record 2 of Set 4 | wanaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=wanaka
# processing Record 3 of Set 4 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sorland
# processing Record 4 of Set 4 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=rio%20gallegos
# processing Record 5 of Set 4 | sayyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sayyan
# processing Record 6 of Set 4 | dolbeau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=dolbeau
# City not found. Skipping....
# processing Record 7 of Set 4 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=souillac
# processing Record 8 of Set 4 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=avera
# processing Record 9 of Set 4 | key west
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=key%20west
# processing Record 10 of Set 4 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=pacific%20grove
# processing Record 11 of Set 4 | taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=taksimo
# processing Record 12 of Set 4 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=zhanaozen
# processing Record 13 of Set 4 | korhogo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=korhogo
# processing Record 14 of Set 4 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nanortalik
# processing Record 15 of Set 4 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=puerto%20ayora
# processing Record 16 of Set 4 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=belushya%20guba
# City not found. Skipping....
# processing Record 17 of Set 4 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=moose%20factory
# processing Record 18 of Set 4 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=baruun-urt
# processing Record 19 of Set 4 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=alta%20floresta
# processing Record 20 of Set 4 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=fairbanks
# processing Record 21 of Set 4 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=krasnoselkup
# City not found. Skipping....
# processing Record 22 of Set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ponta%20do%20sol
# processing Record 23 of Set 4 | ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ukiah
# processing Record 24 of Set 4 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=saint-joseph
# processing Record 25 of Set 4 | anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=anloga
# processing Record 26 of Set 4 | jerome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=jerome
# processing Record 27 of Set 4 | gerash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=gerash
# processing Record 28 of Set 4 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nizhneyansk
# City not found. Skipping....
# processing Record 29 of Set 4 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=lasa
# processing Record 30 of Set 4 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=usinsk
# processing Record 31 of Set 4 | ocean city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ocean%20city
# processing Record 32 of Set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=cidreira
# processing Record 33 of Set 4 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=chuy
# processing Record 34 of Set 4 | apache junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=apache%20junction
# processing Record 35 of Set 4 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=torbay
# processing Record 36 of Set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=clyde%20river
# processing Record 37 of Set 4 | manavalakurichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=manavalakurichi
# processing Record 38 of Set 4 | nova russas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nova%20russas
# processing Record 39 of Set 4 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=portland
# processing Record 40 of Set 4 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bambous%20virieux
# processing Record 41 of Set 4 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=pevek
# processing Record 42 of Set 4 | cockburn harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=cockburn%20harbour
# City not found. Skipping....
# processing Record 43 of Set 4 | yagodnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=yagodnoye
# processing Record 44 of Set 4 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=axim
# processing Record 45 of Set 4 | uwajima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=uwajima
# processing Record 46 of Set 4 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=baykit
# processing Record 47 of Set 4 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=belmonte
# processing Record 48 of Set 4 | elizabeth city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=elizabeth%20city
# processing Record 49 of Set 4 | ajdabiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ajdabiya
# processing Record 50 of Set 4 | ourem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ourem
# processing Record 1 of Set 5 | hearst
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=hearst
# processing Record 2 of Set 5 | ayagoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ayagoz
# processing Record 3 of Set 5 | juterbog
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=juterbog
# processing Record 4 of Set 5 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=hovd
# processing Record 5 of Set 5 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=san%20cristobal
# processing Record 6 of Set 5 | somerset east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=somerset%20east
# processing Record 7 of Set 5 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=coquimbo
# processing Record 8 of Set 5 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=faanui
# processing Record 9 of Set 5 | palia kalan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=palia%20kalan
# processing Record 10 of Set 5 | huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=huilong
# processing Record 11 of Set 5 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=shingu
# processing Record 12 of Set 5 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=mahebourg
# processing Record 13 of Set 5 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=salalah
# processing Record 14 of Set 5 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=saint-francois
# processing Record 15 of Set 5 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=vostok
# processing Record 16 of Set 5 | prievidza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=prievidza
# processing Record 17 of Set 5 | coevorden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=coevorden
# processing Record 18 of Set 5 | matucana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=matucana
# processing Record 19 of Set 5 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kununurra
# processing Record 20 of Set 5 | bogande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bogande
# processing Record 21 of Set 5 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bethel
# processing Record 22 of Set 5 | madang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=madang
# processing Record 23 of Set 5 | syracuse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=syracuse
# processing Record 24 of Set 5 | eugene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=eugene
# processing Record 25 of Set 5 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bengkulu
# City not found. Skipping....
# processing Record 26 of Set 5 | turinskaya sloboda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=turinskaya%20sloboda
# processing Record 27 of Set 5 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=saskylakh
# processing Record 28 of Set 5 | port angeles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=port%20angeles
# processing Record 29 of Set 5 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=caravelas
# processing Record 30 of Set 5 | gisborne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=gisborne
# processing Record 31 of Set 5 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=inirida
# processing Record 32 of Set 5 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=chapais
# processing Record 33 of Set 5 | kumluca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kumluca
# processing Record 34 of Set 5 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=codrington
# processing Record 35 of Set 5 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=moron
# processing Record 36 of Set 5 | erdemli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=erdemli
# processing Record 37 of Set 5 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tautira
# processing Record 38 of Set 5 | mocambique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=mocambique
# City not found. Skipping....
# processing Record 39 of Set 5 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=buala
# processing Record 40 of Set 5 | burns lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=burns%20lake
# processing Record 41 of Set 5 | sechelt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sechelt
# processing Record 42 of Set 5 | machali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=machali
# City not found. Skipping....
# processing Record 43 of Set 5 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=iqaluit
# processing Record 44 of Set 5 | candawaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=candawaga
# City not found. Skipping....
# processing Record 45 of Set 5 | krasnogorskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=krasnogorskoye
# processing Record 46 of Set 5 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=dingle
# processing Record 47 of Set 5 | opochka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=opochka
# processing Record 48 of Set 5 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=lebu
# processing Record 49 of Set 5 | shimanovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=shimanovsk
# processing Record 50 of Set 5 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=narsaq
# processing Record 1 of Set 6 | jundia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=jundia
# processing Record 2 of Set 6 | elliot lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=elliot%20lake
# processing Record 3 of Set 6 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nhulunbuy
# processing Record 4 of Set 6 | mikhaylovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=mikhaylovskoye
# processing Record 5 of Set 6 | razole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=razole
# processing Record 6 of Set 6 | curup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=curup
# processing Record 7 of Set 6 | iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=iquique
# processing Record 8 of Set 6 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tumannyy
# City not found. Skipping....
# processing Record 9 of Set 6 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=samusu
# City not found. Skipping....
# processing Record 10 of Set 6 | governador valadares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=governador%20valadares
# processing Record 11 of Set 6 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=yumen
# processing Record 12 of Set 6 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=havelock
# processing Record 13 of Set 6 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ribeira%20grande
# processing Record 14 of Set 6 | bursol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bursol
# City not found. Skipping....
# processing Record 15 of Set 6 | ichihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ichihara
# processing Record 16 of Set 6 | ciras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ciras
# City not found. Skipping....
# processing Record 17 of Set 6 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=esperance
# processing Record 18 of Set 6 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=roma
# processing Record 19 of Set 6 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sentyabrskiy
# City not found. Skipping....
# processing Record 20 of Set 6 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sao%20filipe
# processing Record 21 of Set 6 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=harper
# processing Record 22 of Set 6 | murakami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=murakami
# processing Record 23 of Set 6 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ugoofaaru
# processing Record 24 of Set 6 | tevriz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tevriz
# processing Record 25 of Set 6 | bundaberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bundaberg
# processing Record 26 of Set 6 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bathsheba
# processing Record 27 of Set 6 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tiksi
# processing Record 28 of Set 6 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=eureka
# processing Record 29 of Set 6 | el alto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=el%20alto
# processing Record 30 of Set 6 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=hay%20river
# processing Record 31 of Set 6 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=toliary
# City not found. Skipping....
# processing Record 32 of Set 6 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=hualmay
# processing Record 33 of Set 6 | yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=yarada
# processing Record 34 of Set 6 | bastia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bastia
# processing Record 35 of Set 6 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=victoria
# processing Record 36 of Set 6 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=norman%20wells
# processing Record 37 of Set 6 | subaytilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=subaytilah
# City not found. Skipping....
# processing Record 38 of Set 6 | seddon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=seddon
# processing Record 39 of Set 6 | tutoia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tutoia
# processing Record 40 of Set 6 | ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ulaanbaatar
# processing Record 41 of Set 6 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=raudeberg
# processing Record 42 of Set 6 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=airai
# processing Record 43 of Set 6 | wewak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=wewak
# processing Record 44 of Set 6 | takanabe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=takanabe
# processing Record 45 of Set 6 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tilichiki
# processing Record 46 of Set 6 | pishin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=pishin
# processing Record 47 of Set 6 | preeceville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=preeceville
# processing Record 48 of Set 6 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=whitehorse
# processing Record 49 of Set 6 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=yulara
# processing Record 50 of Set 6 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ketchikan
# processing Record 1 of Set 7 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nome
# processing Record 2 of Set 7 | oum hadjer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=oum%20hadjer
# processing Record 3 of Set 7 | wamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=wamba
# processing Record 4 of Set 7 | taree
# ...
# processing Record 27 of Set 11 | licuriciu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=licuriciu
# processing Record 28 of Set 11 | modra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=modra
# processing Record 29 of Set 11 | neuquen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=neuquen
# processing Record 30 of Set 11 | roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=roebourne
# processing Record 31 of Set 11 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=adrar
# processing Record 32 of Set 11 | el balyana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=el%20balyana
# City not found. Skipping....
# processing Record 33 of Set 11 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=lorengau
# processing Record 34 of Set 11 | gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=gornopravdinsk
# processing Record 35 of Set 11 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=hami
# processing Record 36 of Set 11 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=itarema
# processing Record 37 of Set 11 | stephenville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=stephenville
# processing Record 38 of Set 11 | kharod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kharod
# processing Record 39 of Set 11 | trelew
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=trelew
# processing Record 40 of Set 11 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sinnamary
# processing Record 41 of Set 11 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=havre-saint-pierre
# processing Record 42 of Set 11 | san pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=san%20pedro
# processing Record 43 of Set 11 | waconia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=waconia
# processing Record 44 of Set 11 | san javier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=san%20javier
# processing Record 45 of Set 11 | kyaikto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kyaikto
# processing Record 46 of Set 11 | beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=beyneu
# processing Record 47 of Set 11 | veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=veraval
# processing Record 48 of Set 11 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=zyryanka
# processing Record 49 of Set 11 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sola
# processing Record 50 of Set 11 | eisiskes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=eisiskes
# processing Record 1 of Set 12 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=viedma
# processing Record 2 of Set 12 | vachi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=vachi
# processing Record 3 of Set 12 | ligayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ligayan
# processing Record 4 of Set 12 | gurgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=gurgan
# City not found. Skipping....
# processing Record 5 of Set 12 | lavumisa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=lavumisa
# processing Record 6 of Set 12 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=pisco
# processing Record 7 of Set 12 | kegayli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kegayli
# City not found. Skipping....
# processing Record 8 of Set 12 | moba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=moba
# processing Record 9 of Set 12 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=aklavik
# processing Record 10 of Set 12 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=port%20lincoln
# processing Record 11 of Set 12 | nsanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nsanje
# processing Record 12 of Set 12 | khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=khani
# processing Record 13 of Set 12 | nurota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nurota
# processing Record 14 of Set 12 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=olafsvik
# City not found. Skipping....
# processing Record 15 of Set 12 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=acapulco
# processing Record 16 of Set 12 | clearlake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=clearlake
# processing Record 17 of Set 12 | tungor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=tungor
# processing Record 18 of Set 12 | pilar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=pilar
# processing Record 19 of Set 12 | krasnorechenskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=krasnorechenskiy
# processing Record 20 of Set 12 | lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=lima
# processing Record 21 of Set 12 | arani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=arani
# processing Record 22 of Set 12 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=roald
# processing Record 23 of Set 12 | gwanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=gwanda
# processing Record 24 of Set 12 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=port%20moresby
# processing Record 25 of Set 12 | grimmen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=grimmen
# processing Record 26 of Set 12 | kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kikwit
# processing Record 27 of Set 12 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sobolevo
# processing Record 28 of Set 12 | kabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kabo
# processing Record 29 of Set 12 | megion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=megion
# processing Record 30 of Set 12 | sovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sovetskiy
# processing Record 31 of Set 12 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=quatre%20cocos
# processing Record 32 of Set 12 | makokou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=makokou
# processing Record 33 of Set 12 | burayevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=burayevo
# processing Record 34 of Set 12 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=yerbogachen
# processing Record 35 of Set 12 | esfarayen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=esfarayen
# processing Record 36 of Set 12 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bubaque
# processing Record 37 of Set 12 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=nabire
# processing Record 38 of Set 12 | labytnangi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=labytnangi
# processing Record 39 of Set 12 | cienaga de flores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=cienaga%20de%20flores
# City not found. Skipping....
# processing Record 40 of Set 12 | henzada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=henzada
# City not found. Skipping....
# processing Record 41 of Set 12 | phan thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=phan%20thiet
# processing Record 42 of Set 12 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=sisimiut
# processing Record 43 of Set 12 | cedar rapids
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=cedar%20rapids
# processing Record 44 of Set 12 | atbasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=atbasar
# processing Record 45 of Set 12 | ciudad bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ciudad%20bolivar
# processing Record 46 of Set 12 | beidao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=beidao
# processing Record 47 of Set 12 | ndele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ndele
# City not found. Skipping....
# processing Record 48 of Set 12 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=taltal
# processing Record 49 of Set 12 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=russell
# processing Record 50 of Set 12 | jhang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=jhang
# processing Record 1 of Set 13 | miranorte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=miranorte
# City not found. Skipping....
# processing Record 2 of Set 13 | malatya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=malatya
# processing Record 3 of Set 13 | corner brook
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=corner%20brook
# processing Record 4 of Set 13 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=mandalgovi
# processing Record 5 of Set 13 | kadykchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kadykchan
# City not found. Skipping....
# processing Record 6 of Set 13 | kerema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kerema
# processing Record 7 of Set 13 | kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=kawalu
# processing Record 8 of Set 13 | smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=smithers
# processing Record 9 of Set 13 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=meulaboh
# processing Record 10 of Set 13 | bytosh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=bytosh
# processing Record 11 of Set 13 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=turukhansk
# processing Record 12 of Set 13 | ust-charyshskaya pristan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=ust-charyshskaya%20pristan
# processing Record 13 of Set 13 | wittmund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=wittmund
# processing Record 14 of Set 13 | iwanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=iwanai
# processing Record 15 of Set 13 | cochabamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=cochabamba
# processing Record 16 of Set 13 | santa marta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=santa%20marta
# processing Record 17 of Set 13 | lujan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=lujan
# processing Record 18 of Set 13 | homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=homer
# processing Record 19 of Set 13 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=maldonado
# processing Record 20 of Set 13 | enshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=enshi
# processing Record 21 of Set 13 | aras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=aras
# processing Record 22 of Set 13 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=te%20anau
# processing Record 23 of Set 13 | prestea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=prestea
# processing Record 24 of Set 13 | butia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=butia
# processing Record 25 of Set 13 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=morondava
# processing Record 26 of Set 13 | socorro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=socorro
# processing Record 27 of Set 13 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9054ee19d35081786b7192946e96baac&q=yar-sale
# ----------------------------------------------
# Data Retrieval Complete
# ----------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame({"City":citi,"Cloudiness":cloudiness,"Country":country,"Date":date,"Humidity":humidity,"Lat":latitude,"Lng":\
                  longitude,"Max Temp":max_temp,"Wind Speed":wind_speed})

df.to_csv(output_data_file)
df.count()
# Out:
# City          556
# Cloudiness    556
# Country       556
# Date          556
# Humidity      556
# Lat           556
# Lng           556
# Max Temp      556
# Wind Speed    556
# dtype: int64

# %%
df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Barrow          74      AR  1562051826        53 -38.31  -60.23
# 1  Karpathos          20      GR  1562051699        73  35.51   27.21
# 2    Cayenne          90      GF  1562051869       100   4.94  -52.33
# 3   Lithakia           0      GR  1562051869        54  37.72   20.83
# 4    Rikitea         100      PF  1562051869        73 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     46.15       15.35
# 1     77.00       24.16
# 2     73.40        2.24
# 3     82.40        5.82
# 4     69.73       19.69

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from datetime import datetime
d=df.loc[0,"Date"]
dateconv = datetime.fromtimestamp(d).strftime('%m/%d/%y')


plt.scatter(df['Lat'],df['Max Temp'], marker="o", facecolors="steelblue", edgecolors="black",
            alpha=0.9)
plt.title("City Latitude vs. Max Temperature"+" ("+str(dateconv)+")")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("../Images/LatitudeVSmaxTemperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df['Lat'],df['Humidity'], marker="o", facecolors="steelblue", edgecolors="black",
            alpha=0.9)
plt.title("City Latitude vs. Humidity"+" ("+str(dateconv)+")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("../Images/LatitudeVShumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df['Lat'],df['Cloudiness'], marker="o", facecolors="steelblue", edgecolors="black",
            alpha=0.9)
plt.title("City Latitude vs. Cloudiness"+" ("+str(dateconv)+")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("../Images/LatitudeVScloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df['Lat'],df['Wind Speed'], marker="o", facecolors="steelblue", edgecolors="black",
            alpha=0.9)
plt.title("City Latitude vs. Wind Speed"+" ("+str(dateconv)+")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("../Images/LatitudeVSwindspeed.png")
